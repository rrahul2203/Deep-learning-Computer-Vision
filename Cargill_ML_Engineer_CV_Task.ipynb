# %% [markdown]
# <a href="https://colab.research.google.com/github/rrahul2203/Deep-learning-Computer-Vision/blob/main/Cargill_ML_Engineer_CV_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CV Task

# %% [markdown]
# You are given the original and degraded versions of a few images. Your task is to write a network which can fix the degraded images.
#
# Complete the function `fix` at the end of the "Evaluation" block so that it can take a degraded image, and return a fixed image (that looks as much like the original non-degraded version as possible). **Read the doc-string of the fix function to see the format it expects, otherwise the displayed images will look extremely strange.**
#
# Before submission, get this notebook in a state such that the `fix` function can directly be called on an image. Also, please make sure that 5 images are displayed in the result block. Without that, your submission will not be evaluated.

# %% [markdown]
# # Setup:

# %% [markdown]
# ## Intended Structure after Setup

# %% [markdown]
# Run the blocks in this section to get the following directory structure:
# ```
# /content
# │
# └───cargill-pubfig831
#     │
#     └───correct
#     │   │
#     │   └───train
#     │   │   │
#     │   │   └───Adam Sandler
#     │   │   │   │   train__000001-000000.jpg
#     │   │   │   │   train__000001-000001.jpg
#     │   │   │   │   train__000001-000002.jpg
#     │   │   │   │   ...
#     │   │   │
#     │   │   └───Alec Baldwin
#     │   │   │   │   train__000002-000000.jpg
#     │   │   │   │   train__000002-000001.jpg
#     │   │   │   │   ...
#     │   │   │
#     │   │   └───Angelina Jolie
#     │   │   │   │   train__000003-000000.jpg
#     │   │   │   │   train__000003-000001.jpg
#     │   │   │   │   ...
#     │   │   │
#     │   │   │ ...
#     │   │
#     │   └───test
#     │       │
#     │       └───Adam Sandler
#     │       │   │   test__000001-000000.jpg
#     │       │   │   test__000001-000001.jpg
#     │       │   │   ...
#     │       │
#     │       └───Alec Baldwin
#     │       │   │   test__000002-000000.jpg
#     │       │   │   ...
#     │       │
#     │       └───Angelina Jolie
#     │       │   │   test__000003-000000.jpg
#     │       │   │   ...
#     │       │
#     │       │ ...
#     │
#     │
#     └───degraded
#         │   <Same directory structure as 'correct'>
# ```

# %% [markdown]
# Every image in the degraded directory is a degraded version of the image with the same name in the correct directory. e.g. `/content/cargill-pubfig831/degraded/Adam Sandler/train__000001-000002.jpg` is the degraded version of `/content/cargill-pubfig831/correct/Adam Sandler/train__000001-000002.jpg`

# %% [markdown]
# ## Installation (pip etc)
# Add any other installation commands you want to in this block.

# %%
# !pip install GPUtil
# !pip install tqdm
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install torchvision
# Out:
# Collecting GPUtil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
# Building wheels for collected packages: GPUtil
#   Building wheel for GPUtil (setup.py) ... done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7411 sha256=02ed9c7f70bb2ef63b0a1fabea6444ee3a7f4b7f5706b12a09c45614caee3066
#   Stored in directory: /root/.cache/pip/wheels/6e/f8/83/534c52482d6da64622ddbf72cd93c35d2ef2881b78fd08ff0c
# Successfully built GPUtil
# Installing collected packages: GPUtil
# Successfully installed GPUtil-1.4.0
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.10.0+cu102)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.19.5)
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0->torchvision) (3.7.4.3)

# %% [markdown]
# ## Downloading and Generating Dataset
# Run this block only once. Do not modify it. Also, don't call the degrade function in your code anywhere. You should treat the degradation process as a black box.

# %%
import os
from tqdm import tqdm
from glob import glob

import cv2
import numpy as np


def degrade(path: str) -> None:
    """Load image at `input_path`, distort and save as `output_path`"""
    SHIFT = 2
    image = cv2.imread(path)
    to_swap = np.random.choice([False, True], image.shape[:2], p=[.8, .2])
    swap_indices = np.where(to_swap[:-SHIFT] & ~to_swap[SHIFT:])
    swap_vals = image[swap_indices[0] + SHIFT, swap_indices[1]]
    image[swap_indices[0] + SHIFT, swap_indices[1]] = image[swap_indices]
    image[swap_indices] = swap_vals
    cv2.imwrite(path, image)

# !wget http://briancbecker.com/files/downloads/pubfig83lfw/pubfig83lfw_raw_in_dirs.zip
# !unzip pubfig83lfw_raw_in_dirs.zip
# !rm pubfig83lfw_raw_in_dirs.zip
# !mkdir cargill-pubfig831
# !mv pubfig83lfw_raw_in_dirs cargill-pubfig831/correct
# !rm -r cargill-pubfig831/correct/distract
# !cp -r cargill-pubfig831/correct cargill-pubfig831/degraded

for image_path in tqdm(glob('cargill-pubfig831/degraded/*/*/*.jpg')):
    degrade(image_path)
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000051.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000052.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000053.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000054.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000055.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000056.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000057.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000058.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000059.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000060.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000061.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000062.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000063.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000064.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000065.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000066.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000067.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000068.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000069.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000070.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000071.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000072.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000073.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000074.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000075.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000076.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000077.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000078.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000079.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000080.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000081.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000082.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000083.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000084.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000085.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000086.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000087.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000088.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000089.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000090.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000091.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000092.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000093.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000094.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000095.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000096.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000097.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000098.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000099.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000100.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000101.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000102.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000103.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Hugh Laurie/train__000036-000104.jpg
#    creating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000000.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000001.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000002.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000003.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000004.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000005.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000006.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000007.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000008.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000009.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000010.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000011.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000012.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000013.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000014.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000015.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000016.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000017.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000018.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000019.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000020.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000021.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000022.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000023.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000024.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000025.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000026.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000027.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000028.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000029.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000030.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000031.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000032.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000033.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000034.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000035.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000036.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000037.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000038.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000039.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000040.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000041.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000042.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000043.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000044.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000045.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000046.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000047.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000048.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000049.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000050.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000051.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jack Nicholson/train__000037-000052.jpg
#    creating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000000.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000001.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000002.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000003.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000004.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000005.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000006.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000007.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000008.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000009.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000010.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000011.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000012.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000013.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000014.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000015.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000016.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000017.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000018.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000019.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000020.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000021.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000022.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000023.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000024.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000025.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000026.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000027.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000028.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000029.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000030.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000031.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000032.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000033.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000034.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000035.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000036.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000037.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000038.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000039.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000040.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000041.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000042.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000043.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000044.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000045.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000046.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000047.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000048.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000049.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000050.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000051.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000052.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000053.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000054.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000055.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000056.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000057.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000058.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000059.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000060.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000061.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000062.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000063.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000064.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000065.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000066.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000067.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000068.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000069.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000070.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000071.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000072.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000073.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000074.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000075.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000076.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000077.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000078.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000079.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000080.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000081.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000082.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000083.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000084.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000085.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000086.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000087.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000088.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000089.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000090.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000091.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000092.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000093.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000094.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000095.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000096.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000097.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000098.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000099.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000100.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000101.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000102.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000103.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000104.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000105.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000106.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000107.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000108.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000109.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000110.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000111.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000112.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000113.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000114.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000115.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000116.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000117.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000118.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000119.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000120.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000121.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000122.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000123.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000124.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000125.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000126.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000127.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000128.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000129.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000130.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000131.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000132.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000133.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000134.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000135.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Aniston/train__000038-000136.jpg
#    creating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000000.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000001.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000002.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000003.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000004.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000005.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000006.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000007.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000008.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000009.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000010.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000011.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000012.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000013.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000014.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000015.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000016.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000017.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000018.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000019.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000020.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000021.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000022.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000023.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000024.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000025.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000026.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000027.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000028.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000029.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000030.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000031.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000032.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000033.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000034.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000035.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000036.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000037.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000038.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000039.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000040.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000041.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000042.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000043.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000044.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000045.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000046.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000047.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000048.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000049.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000050.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000051.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000052.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000053.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000054.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000055.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000056.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000057.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000058.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000059.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000060.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000061.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000062.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000063.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000064.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000065.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000066.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000067.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000068.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000069.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000070.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000071.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000072.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000073.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000074.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000075.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000076.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000077.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Lopez/train__000039-000078.jpg
#    creating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000000.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000001.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000002.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000003.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000004.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000005.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000006.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000007.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000008.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000009.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000010.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000011.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000012.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000013.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000014.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000015.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000016.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000017.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000018.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000019.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000020.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000021.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000022.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000023.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000024.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000025.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000026.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000027.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000028.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000029.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000030.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000031.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000032.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000033.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000034.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000035.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000036.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000037.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000038.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000039.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000040.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000041.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000042.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000043.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000044.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000045.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000046.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000047.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000048.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000049.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000050.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000051.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000052.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000053.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000054.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000055.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000056.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000057.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000058.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000059.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000060.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000061.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000062.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000063.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jennifer Love Hewitt/train__000040-000064.jpg
#    creating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000000.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000001.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000002.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000003.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000004.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000005.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000006.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000007.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000008.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000009.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000010.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000011.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000012.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000013.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000014.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000015.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000016.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000017.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000018.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000019.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000020.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000021.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000022.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000023.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000024.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000025.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000026.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000027.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000028.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000029.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000030.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000031.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000032.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000033.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000034.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000035.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000036.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000037.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000038.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000039.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000040.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000041.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000042.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000043.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000044.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000045.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000046.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000047.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000048.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000049.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000050.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000051.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000052.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000053.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000054.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000055.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000056.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000057.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000058.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000059.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000060.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000061.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000062.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000063.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000064.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000065.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000066.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000067.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000068.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000069.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000070.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000071.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000072.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000073.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000074.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000075.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000076.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000077.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000078.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000079.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000080.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000081.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000082.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000083.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000084.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000085.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000086.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000087.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000088.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000089.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000090.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000091.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000092.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000093.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000094.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000095.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000096.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000097.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000098.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000099.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000100.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000101.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000102.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000103.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000104.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000105.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000106.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000107.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000108.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000109.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000110.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000111.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Alba/train__000041-000112.jpg
#    creating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000000.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000001.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000002.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000003.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000004.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000005.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000006.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000007.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000008.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000009.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000010.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000011.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000012.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000013.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000014.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000015.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000016.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000017.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000018.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000019.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000020.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000021.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000022.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000023.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000024.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000025.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000026.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000027.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000028.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000029.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000030.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000031.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000032.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000033.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000034.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000035.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000036.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000037.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000038.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000039.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000040.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000041.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000042.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000043.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000044.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000045.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000046.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000047.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000048.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000049.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000050.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000051.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000052.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Jessica Simpson/train__000042-000053.jpg
# ...
#    creating: pubfig83lfw_raw_in_dirs/train/Will Smith/
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000000.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000001.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000002.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000003.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000004.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000005.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000006.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000007.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000008.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000009.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000010.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000011.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000012.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000013.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000014.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000015.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000016.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000017.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000018.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000019.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000020.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000021.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000022.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000023.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000024.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000025.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000026.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000027.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000028.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000029.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000030.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000031.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000032.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000033.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000034.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000035.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000036.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000037.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000038.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000039.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000040.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000041.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000042.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000043.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000044.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000045.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000046.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000047.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000048.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000049.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000050.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000051.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000052.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000053.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000054.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000055.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000056.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000057.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000058.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000059.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000060.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000061.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000062.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000063.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000064.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000065.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000066.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000067.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000068.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000069.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000070.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000071.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000072.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000073.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000074.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Will Smith/train__000082-000075.jpg
#    creating: pubfig83lfw_raw_in_dirs/train/Zac Efron/
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000000.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000001.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000002.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000003.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000004.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000005.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000006.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000007.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000008.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000009.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000010.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000011.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000012.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000013.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000014.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000015.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000016.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000017.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000018.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000019.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000020.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000021.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000022.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000023.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000024.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000025.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000026.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000027.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000028.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000029.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000030.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000031.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000032.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000033.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000034.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000035.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000036.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000037.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000038.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000039.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000040.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000041.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000042.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000043.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000044.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000045.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000046.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000047.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000048.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000049.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000050.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000051.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000052.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000053.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000054.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000055.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000056.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000057.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000058.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000059.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000060.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000061.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000062.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000063.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000064.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000065.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000066.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000067.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000068.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000069.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000070.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000071.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000072.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000073.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000074.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000075.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000076.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000077.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000078.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000079.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000080.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000081.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000082.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000083.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000084.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000085.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000086.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000087.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000088.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000089.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000090.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000091.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000092.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000093.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000094.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000095.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000096.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000097.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000098.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000099.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000100.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000101.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000102.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000103.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000104.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000105.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000106.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000107.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000108.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000109.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000110.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000111.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000112.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000113.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000114.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000115.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000116.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000117.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000118.jpg
#   inflating: pubfig83lfw_raw_in_dirs/train/Zac Efron/train__000083-000119.jpg
# 100%|██████████| 13002/13002 [01:21<00:00, 158.76it/s]

# %% [markdown]
# # **Checking Free Memory**
# This block is just so that you can have an idea of the resources you have at hand on the Google Collab system.

# %%
import psutil
import humanize
import os
import GPUtil as GPU
gpu = GPU.getGPUs()[0]
process = psutil.Process(os.getpid())
print(f"Gen RAM: Free {humanize.naturalsize(psutil.virtual_memory().available)} | Proc size {humanize.naturalsize(process.memory_info().rss)}")
print(f"GPU RAM: Free {gpu.memoryFree:.0f}MB | Used {gpu.memoryUsed:.0f}MB | Util {gpu.memoryUtil*100:.0f}% | Total {gpu.memoryTotal:.0f}MB")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-54934d324558> in <module>()
#       3 import os
#       4 import GPUtil as GPU
# ----> 5 gpu = GPU.getGPUs()[0]
#       6 process = psutil.Process(os.getpid())
#       7 print(f"Gen RAM: Free {humanize.naturalsize(psutil.virtual_memory().available)} | Proc size {humanize.naturalsize(process.memory_info().rss)}")
#
# IndexError: list index out of range

# %% [markdown]
# # **Main Code**

# %% [markdown]
# ## Imports

# %%
from PIL import Image
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import torchvision
import os
from torchvision import transforms as T
from collections import defaultdict, deque
import datetime
import errno
import os
import time
import torch.distributed as dist
import math

# %% [markdown]
# ### **Constants and Hyperparemeters**

# %%
#use gpu or not 
gpu = False
device = torch.device("cpu")

#Parameters for optimizers
lr = 1e-04
betas=(0.9, 0.999)
eps=1e-08
weight_decay=0.0005

#number of training iterations
num_iters = 30
#number of steps to take before saving an output image
#saving_frequency = 250
#where to put the output
#output_name = 'output/output'

# %%
class SmoothedValue(object):
    """Track a series of values and provide access to smoothed values over a
    window or the global series average.
    """

    def __init__(self, window_size=20, fmt=None):
        if fmt is None:
            fmt = "{median:.4f} ({global_avg:.4f})"
        self.deque = deque(maxlen=window_size)
        self.total = 0.0
        self.count = 0
        self.fmt = fmt

    def update(self, value, n=1):
        self.deque.append(value)
        self.count += n
        self.total += value * n

    def synchronize_between_processes(self):
        """
        Warning: does not synchronize the deque!
        """
        if not is_dist_avail_and_initialized():
            return
        t = torch.tensor([self.count, self.total], dtype=torch.float64, device='cuda')
        dist.barrier()
        dist.all_reduce(t)
        t = t.tolist()
        self.count = int(t[0])
        self.total = t[1]

    @property
    def median(self):
        d = torch.tensor(list(self.deque))
        return d.median().item()

    @property
    def avg(self):
        d = torch.tensor(list(self.deque), dtype=torch.float32)
        return d.mean().item()

    @property
    def global_avg(self):
        return self.total / self.count

    @property
    def max(self):
        return max(self.deque)

    @property
    def value(self):
        return self.deque[-1]

    def __str__(self):
        return self.fmt.format(
            median=self.median,
            avg=self.avg,
            global_avg=self.global_avg,
            max=self.max,
            value=self.value)


def all_gather(data):
    """
    Run all_gather on arbitrary picklable data (not necessarily tensors)
    Args:
        data: any picklable object
    Returns:
        list[data]: list of data gathered from each rank
    """
    world_size = get_world_size()
    if world_size == 1:
        return [data]
    data_list = [None] * world_size
    dist.all_gather_object(data_list, data)
    return data_list


def reduce_dict(input_dict, average=True):
    """
    Args:
        input_dict (dict): all the values will be reduced
        average (bool): whether to do average or sum
    Reduce the values in the dictionary from all processes so that all processes
    have the averaged results. Returns a dict with the same fields as
    input_dict, after reduction.
    """
    world_size = get_world_size()
    if world_size < 2:
        return input_dict
    with torch.no_grad():
        names = []
        values = []
        # sort the keys so that they are consistent across processes
        for k in sorted(input_dict.keys()):
            names.append(k)
            values.append(input_dict[k])
        values = torch.stack(values, dim=0)
        dist.all_reduce(values)
        if average:
            values /= world_size
        reduced_dict = {k: v for k, v in zip(names, values)}
    return reduced_dict

class MetricLogger(object):
    def __init__(self, delimiter="\t"):
        self.meters = defaultdict(SmoothedValue)
        self.delimiter = delimiter

    def update(self, **kwargs):
        for k, v in kwargs.items():
            if isinstance(v, torch.Tensor):
                v = v.item()
            assert isinstance(v, (float, int))
            self.meters[k].update(v)

    def __getattr__(self, attr):
        if attr in self.meters:
            return self.meters[attr]
        if attr in self.__dict__:
            return self.__dict__[attr]
        raise AttributeError("'{}' object has no attribute '{}'".format(
            type(self).__name__, attr))

    def __str__(self):
        loss_str = []
        for name, meter in self.meters.items():
            loss_str.append(
                "{}: {}".format(name, str(meter))
            )
        return self.delimiter.join(loss_str)

    def synchronize_between_processes(self):
        for meter in self.meters.values():
            meter.synchronize_between_processes()

    def add_meter(self, name, meter):
        self.meters[name] = meter

    def log_every(self, iterable, print_freq, header=None):
        i = 0
        if not header:
            header = ''
        start_time = time.time()
        end = time.time()
        iter_time = SmoothedValue(fmt='{avg:.4f}')
        data_time = SmoothedValue(fmt='{avg:.4f}')
        space_fmt = ':' + str(len(str(len(iterable)))) + 'd'
        if torch.cuda.is_available():
            log_msg = self.delimiter.join([
                header,
                '[{0' + space_fmt + '}/{1}]',
                'eta: {eta}',
                '{meters}',
                'time: {time}',
                'data: {data}',
                'max mem: {memory:.0f}'
            ])
        else:
            log_msg = self.delimiter.join([
                header,
                '[{0' + space_fmt + '}/{1}]',
                'eta: {eta}',
                '{meters}',
                'time: {time}',
                'data: {data}'
            ])
        MB = 1024.0 * 1024.0
        for obj in iterable:
            data_time.update(time.time() - end)
            yield obj
            iter_time.update(time.time() - end)
            if i % print_freq == 0 or i == len(iterable) - 1:
                eta_seconds = iter_time.global_avg * (len(iterable) - i)
                eta_string = str(datetime.timedelta(seconds=int(eta_seconds)))
                if torch.cuda.is_available():
                    print(log_msg.format(
                        i, len(iterable), eta=eta_string,
                        meters=str(self),
                        time=str(iter_time), data=str(data_time),
                        memory=torch.cuda.max_memory_allocated() / MB))
                else:
                    print(log_msg.format(
                        i, len(iterable), eta=eta_string,
                        meters=str(self),
                        time=str(iter_time), data=str(data_time)))
            i += 1
            end = time.time()
        total_time = time.time() - start_time
        total_time_str = str(datetime.timedelta(seconds=int(total_time)))
        print('{} Total time: {} ({:.4f} s / it)'.format(
            header, total_time_str, total_time / len(iterable)))

# %%
def tensor_to_img(tensor, filename):
  tensor = tensor.view(tensor.shape[1:])
  if gpu:
    tensor = tensor.cuda()
  tensor_to_img = torchvision.transforms.Compose([torchvision.transforms.ToPILImage()])
  img = tensor_to_img(tensor)
  img.save(filename)

def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

def get_transform(train):
    transforms = []
    transforms.append(T.ToTensor())
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

def warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor):
    def f(x):
        if x >= warmup_iters:
            return 1
        alpha = float(x) / warmup_iters
        return warmup_factor * (1 - alpha) + alpha

    return torch.optim.lr_scheduler.LambdaLR(optimizer, f)

def collate_fn(batch):
    return tuple(zip(*batch))

# %%
class ImageDatasets(torch.utils.data.Dataset):
  def __init__(self, correct, degraded, transform = None):
    self.correct_root = correct
    self.degraded_root = degraded
    self.images_correct = getListOfFiles(self.correct_root)
    self.images_degraded = getListOfFiles(self.degraded_root)
    self.transform = transform

  
  def __getitem__(self, idx):
    correct_img_path=self.images_correct[idx]
    degraded_img_path = self.images_degraded[idx]   
    img = Image.open(degraded_img_path)
    target = Image.open(correct_img_path)

    if self.transform:
      img = self.transform(img)
      target = self.transform(target)

    return img, target 

  def __len__(self):
    return len(self.images_degraded)

# %% [markdown]
# ### Models

# %%
class pixel_shuffle_upsampling(nn.Module):
    def __init__(self):
        super(pixel_shuffle_upsampling, self).__init__()
        self.dconv_1 = nn.Conv2d(3, 8, 5, stride=2, padding=2)
        self.dbn_1 = nn.BatchNorm2d(8)

        self.dconv_2 = nn.Conv2d(8, 16, 5, stride=2, padding=2)
        self.dbn_2 = nn.BatchNorm2d(16)

        self.dconv_3 = nn.Conv2d(16, 32, 5, stride=2, padding=2)
        self.dbn_3 = nn.BatchNorm2d(32)
        self.sconv_3 = nn.Conv2d(32, 4, 5, stride=1, padding=2)

        self.dconv_4 = nn.Conv2d(32, 64, 5, stride=2, padding=2)
        self.dbn_4 = nn.BatchNorm2d(64)
        self.sconv_4 = nn.Conv2d(64, 4, 5, stride=1, padding=2)

        self.dconv_5 = nn.Conv2d(64, 128, 5, stride=2, padding=2)
        self.dbn_5 = nn.BatchNorm2d(128)
        self.sconv_5 = nn.Conv2d(128, 4, 5, stride=1, padding=2)

        self.dconv_6 = nn.Conv2d(128, 256, 5, stride=2, padding=2)
        self.dbn_6 = nn.BatchNorm2d(256)

        self.uconv_5 = nn.Conv2d(68, 128, 5, stride=1, padding=2)
        self.ubn_5 = nn.BatchNorm2d(128)

        self.uconv_4 = nn.Conv2d(36, 64, 5, stride=1, padding=2)
        self.ubn_4 = nn.BatchNorm2d(64)

        self.uconv_3 = nn.Conv2d(20, 32, 5, stride=1, padding=2)
        self.ubn_3 = nn.BatchNorm2d(32)

        self.uconv_2 = nn.Conv2d(8, 16, 5, stride=1, padding=2)
        self.ubn_2 = nn.BatchNorm2d(16)

        self.uconv_1 = nn.Conv2d(4, 16, 8, stride=1, padding=2)
        self.ubn_1 = nn.BatchNorm2d(16)

        self.outconv = nn.Conv2d(4, 3, 5, stride=1, padding=2)
        self.outbn = nn.BatchNorm2d(3)

        
    def forward(self, noise):
        down_1 = self.dconv_1(noise)
        down_1 = self.dbn_1(down_1)
        down_1 = F.leaky_relu(down_1)
       
        down_2 = self.dconv_2(down_1)
        down_2 = self.dbn_2(down_2)
        down_2 = F.leaky_relu(down_2)
     
        down_3 = self.dconv_3(down_2)
        down_3 = self.dbn_3(down_3)
        down_3 = F.leaky_relu(down_3)
        skip_3 = self.sconv_3(down_3)
        
        down_4 = self.dconv_4(down_3)
        down_4 = self.dbn_4(down_4)
        down_4 = F.leaky_relu(down_4)
        skip_4 = self.sconv_4(down_4)
        
        down_5 = self.dconv_5(down_4)
        down_5 = self.dbn_5(down_5)
        down_5 = F.leaky_relu(down_5)
        skip_5 = self.sconv_5(down_5)
      
        down_6 = self.dconv_6(down_5)
        down_6 = self.dbn_6(down_6)
        down_6 = F.leaky_relu(down_6)
        
        up_5 = F.pixel_shuffle(down_6, 2)
        up_5 = torch.cat([up_5, skip_5], 1)
        up_5 = self.uconv_5(up_5)
        up_5 = self.ubn_5(up_5)
        up_5 = F.leaky_relu(up_5)

        up_4 = F.pixel_shuffle(up_5, 2)
        up_4 = torch.cat([up_4, skip_4], 1)
        up_4 = self.uconv_4(up_4)
        up_4 = self.ubn_4(up_4)
        up_4 = F.leaky_relu(up_4)
        
        up_3 = F.pixel_shuffle(up_4, 2)
        up_3 = torch.cat([up_3, skip_3], 1)
        up_3 = self.uconv_3(up_3)
        up_3 = self.ubn_3(up_3)
        up_3 = F.leaky_relu(up_3)

        up_2 = F.pixel_shuffle(up_3, 2)
        up_2 = self.uconv_2(up_2)
        up_2 = self.ubn_2(up_2)
        up_2 = F.leaky_relu(up_2)

        up_1 = F.pixel_shuffle(up_2, 2)
        up_1 = self.uconv_1(up_1)
        up_1 = self.ubn_1(up_1)
        up_1 = F.leaky_relu(up_1)
        
        out = F.pixel_shuffle(up_1, 2)
        out = self.outconv(out)
        out = self.outbn(out)
        out = F.sigmoid(out)
        
        return out

# %%
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=100):
  model.train()
  metric_logger = MetricLogger(delimiter="  ")
  metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
  header = 'Epoch: [{}]'.format(epoch)
  
  lr_scheduler = None
  if epoch==0:
    warmup_factor = 1./1000
    warmup_iters = min(1000, len(data_loader)-1)
    lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)
  
  for images, targets in metric_logger.log_every(data_loader, print_freq, header):
    #import ipdb; ipdb.set_trace()
    images = torch.stack(list(images), dim=0).to(device)
    targets = torch.stack(list(targets), dim=0).to(device)

    preds = model(images)

    losses = torch.sum((targets-preds)**2)
    loss_value = losses.item()
    if not math.isfinite(loss_value):
      print("Loss is {}, stopping training".format(loss_value))
      print(loss_dict_reduced)
      sys.exit(1)

    optimizer.zero_grad()
    losses.backward()
    optimizer.step()

    if lr_scheduler is not None:
      lr_scheduler.step()

    metric_logger.update(loss=losses)
    metric_logger.update(lr=optimizer.param_groups[0]["lr"])

  return metric_logger

@torch.no_grad()
def evaluate(model, data_loader, device):
  n_threads = torch.get_num_threads()
  # FIXME remove this and make paste_masks_in_image run on the GPU
  torch.set_num_threads(1)
  cpu_device = torch.device("cpu")
  model.eval()
  metric_logger = MetricLogger(delimiter="  ")
  header = 'Test:'
   
  for images, targets in metric_logger.log_every(data_loader, 100, header):
    images = torch.stack(list(images), dim=0).to(device)
    targets = torch.stack(list(targets), dim=0).to(device)
    
    if torch.cuda.is_available():
      torch.cuda.synchronize()
    
    model_time = time.time()
    outputs = model(images)
    model_time = time.time() - model_time

    losses = torch.sum((targets-outputs)**2)
    loss_value = losses.item()
    metric_logger.update(loss=losses)

  return metric_logger

# %%
def main():
  #datasets
  train_correct='/content/cargill-pubfig831/correct/train/'
  train_degraded='/content/cargill-pubfig831/degraded/train/'
  test_correct ='/content/cargill-pubfig831/correct/test/'
  test_degraded = '/content/cargill-pubfig831/degraded/test/'

  save_filename ='best-model.h5'

  train_dataset = ImageDatasets(train_correct, train_degraded, get_transform(train=True))
  test_dataset = ImageDatasets(test_correct, test_degraded, get_transform(train=False))

  ##Random shuffling of the datasets 
  indices = torch.randperm(len(train_dataset)).tolist()
  train_dataset = torch.utils.data.Subset(train_dataset, indices)

  test_indices = torch.randperm(len(test_dataset)).tolist()
  test_dataset = torch.utils.data.Subset(test_dataset, test_indices[:1000])

  train_data_loader =  torch.utils.data.DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=4, collate_fn=collate_fn)
  test_data_loader =  torch.utils.data.DataLoader(test_dataset, batch_size=8, shuffle=True, num_workers=4, collate_fn=collate_fn)
  
  model = pixel_shuffle_upsampling()
 
  device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
  model.to(device)

  
  ##Adam Optimizer
  optimizer = torch.optim.Adam(model.parameters(), lr=lr, betas = betas, eps=eps, weight_decay=weight_decay)

  ##Learning rate scheduler 
  lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,step_size=3, gamma=0.1)

  for epoch in tqdm(range(num_iters)):                                                 
    train_one_epoch(model, optimizer,train_data_loader, device, epoch, print_freq=100)
    torch.save(model.state_dict(), save_filename)
    lr_scheduler.step()
    evaluate(model, test_data_loader, device)
    
  if gpu:
    torch.cuda.empty_cache()

# %%
main()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|          | 0/30 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1805: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch: [0]  [   0/1090]  eta: 0:23:35  lr: 0.000000  loss: 204685.4844 (204685.4844)  time: 1.2984  data: 0.4216
# Epoch: [0]  [ 100/1090]  eta: 0:09:08  lr: 0.000010  loss: 164263.9375 (182687.0043)  time: 0.5465  data: 0.0111
# Epoch: [0]  [ 200/1090]  eta: 0:08:11  lr: 0.000020  loss: 132932.9219 (165125.4501)  time: 0.5495  data: 0.0124
# Epoch: [0]  [ 300/1090]  eta: 0:07:14  lr: 0.000030  loss: 105446.5859 (149389.5521)  time: 0.5468  data: 0.0118
# Epoch: [0]  [ 400/1090]  eta: 0:06:19  lr: 0.000040  loss: 98244.1953 (137769.5416)  time: 0.5475  data: 0.0111
# Epoch: [0]  [ 500/1090]  eta: 0:05:24  lr: 0.000050  loss: 95197.1094 (129619.0786)  time: 0.5514  data: 0.0119
# Epoch: [0]  [ 600/1090]  eta: 0:04:28  lr: 0.000060  loss: 78818.0625 (122000.7563)  time: 0.5378  data: 0.0108
# Epoch: [0]  [ 700/1090]  eta: 0:03:33  lr: 0.000070  loss: 84921.4531 (116091.1047)  time: 0.5471  data: 0.0117
# Epoch: [0]  [ 800/1090]  eta: 0:02:38  lr: 0.000080  loss: 69939.5234 (110455.7797)  time: 0.5493  data: 0.0120
# Epoch: [0]  [ 900/1090]  eta: 0:01:44  lr: 0.000090  loss: 68955.0078 (105760.1729)  time: 0.5515  data: 0.0114
# Epoch: [0]  [1000/1090]  eta: 0:00:49  lr: 0.000100  loss: 61298.5195 (101700.9486)  time: 0.5490  data: 0.0112
# Epoch: [0]  [1089/1090]  eta: 0:00:00  lr: 0.000100  loss: 63339.6328 (98501.8539)  time: 0.5410  data: 0.0112
# Epoch: [0] Total time: 0:09:57 (0.5481 s / it)
# Test:  [  0/125]  eta: 0:01:25  loss: 55999.3125 (55999.3125)  time: 0.6813  data: 0.2997
# Test:  [100/125]  eta: 0:00:04  loss: 48363.1836 (47643.1465)  time: 0.1767  data: 0.0121
#   3%|▎         | 1/30 [10:19<4:59:35, 619.86s/it]
# Test:  [124/125]  eta: 0:00:00  loss: 48542.5898 (47804.3871)  time: 0.1689  data: 0.0116
# Test: Total time: 0:00:22 (0.1792 s / it)
# Epoch: [1]  [   0/1090]  eta: 0:21:31  lr: 0.000100  loss: 77644.6406 (77644.6406)  time: 1.1847  data: 0.3933
# Epoch: [1]  [ 100/1090]  eta: 0:09:10  lr: 0.000100  loss: 57105.4883 (60726.5292)  time: 0.5493  data: 0.0119
# Epoch: [1]  [ 200/1090]  eta: 0:08:11  lr: 0.000100  loss: 61795.2188 (61403.5934)  time: 0.5485  data: 0.0117
# Epoch: [1]  [ 300/1090]  eta: 0:07:16  lr: 0.000100  loss: 54634.5898 (60355.6973)  time: 0.5504  data: 0.0120
# Epoch: [1]  [ 400/1090]  eta: 0:06:20  lr: 0.000100  loss: 55585.1133 (59986.1554)  time: 0.5483  data: 0.0118
# Epoch: [1]  [ 500/1090]  eta: 0:05:25  lr: 0.000100  loss: 60578.7070 (59959.9532)  time: 0.5544  data: 0.0129
# Epoch: [1]  [ 600/1090]  eta: 0:04:30  lr: 0.000100  loss: 52929.6289 (59501.7621)  time: 0.5556  data: 0.0128
# Epoch: [1]  [ 700/1090]  eta: 0:03:35  lr: 0.000100  loss: 61076.6172 (59480.1500)  time: 0.5497  data: 0.0118
# Epoch: [1]  [ 800/1090]  eta: 0:02:40  lr: 0.000100  loss: 54868.4883 (58981.6596)  time: 0.5530  data: 0.0110
# Epoch: [1]  [ 900/1090]  eta: 0:01:45  lr: 0.000100  loss: 55302.1211 (58610.0567)  time: 0.5561  data: 0.0124
# Epoch: [1]  [1000/1090]  eta: 0:00:49  lr: 0.000100  loss: 51453.6328 (58187.2879)  time: 0.5571  data: 0.0120
# Epoch: [1]  [1089/1090]  eta: 0:00:00  lr: 0.000100  loss: 52216.6172 (57900.7161)  time: 0.5448  data: 0.0120
# Epoch: [1] Total time: 0:10:03 (0.5532 s / it)
# Test:  [  0/125]  eta: 0:01:24  loss: 34671.5039 (34671.5039)  time: 0.6762  data: 0.2303
# Test:  [100/125]  eta: 0:00:04  loss: 38332.2656 (39140.1106)  time: 0.1769  data: 0.0120
#   7%|▋         | 2/30 [20:45<4:50:50, 623.22s/it]
# Test:  [124/125]  eta: 0:00:00  loss: 37504.3359 (38940.2676)  time: 0.1678  data: 0.0116
# Test: Total time: 0:00:22 (0.1801 s / it)
# Epoch: [2]  [   0/1090]  eta: 0:21:40  lr: 0.000100  loss: 68788.9141 (68788.9141)  time: 1.1934  data: 0.2562
#   7%|▋         | 2/30 [21:02<4:54:39, 631.40s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-263240bbee7e> in <module>()
# ----> 1 main()
#
# <ipython-input-11-87dd090c8b86> in main()
#      34
#      35   for epoch in tqdm(range(num_iters)):
# ---> 36     train_one_epoch(model, optimizer,train_data_loader, device, epoch, print_freq=100)
#      37     torch.save(model.state_dict(), save_filename)
#      38     lr_scheduler.step()
#
# <ipython-input-10-b5dafa71a39d> in train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq)
#      26
#      27     optimizer.zero_grad()
# ---> 28     losses.backward()
#      29     optimizer.step()
#      30
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluation

# %%
def fix(image: np.ndarray) -> np.ndarray:
    """
    This function should take a degraded image in BGR format as a 250x250x3
    numpy array with dtype np.uint8, and return its fixed version in the same format.

    Make sure you don't return floating point values, or RGB instead of BGR, else the
    image will look completely wrong when displayed.
    """

# %% [markdown]
# # Results
# Run this block after you're done to look at some of the results of the fix function. Do not change this block in any way. Instead write the fix function in a way that makes sure that this block works.

# %%
# %matplotlib inline

import os
import random
from glob import glob

import cv2
import matplotlib.pyplot as plt
import numpy as np

NUM_DISPLAY = 5

files = glob('/content/cargill-pubfig831/correct/test/*/*')
grid = []

for path in random.sample(files, NUM_DISPLAY):
    correct = cv2.imread(path)
    split = path.split('/')
    degraded = cv2.imread('/'.join([*split[:3], 'degraded', *split[4:]]))
    fixed = fix(degraded)
    grid.append(np.column_stack([degraded, fixed, correct]))

image = np.row_stack(grid)
dpi = float(plt.rcParams['figure.dpi'])
figsize = image.shape[1] / dpi, image.shape[0] / dpi
ax = plt.figure(figsize=figsize).add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(image[..., ::-1])
plt.show()
